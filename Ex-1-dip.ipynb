# %% [markdown]
#  ## EXP-1 Image Handling and Pixel Transformations Using OpenCV
#  ## Name:b.deepak sudharshan
#  ## Register number:212225230045

# %% [raw]
# Step1:
# Load an image from your local directory and display it.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# Read the image using OpenCV
img = cv2.imread('Qno. 1.jpg', cv2.IMREAD_COLOR)

# %%
# Convert BGR (OpenCV's default) to RGB (Matplotlib's expected color order)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Display the image using Matplotlib
plt.imshow(img_rgb, cmap='viridis')  # You can change 'viridis' to another cmap or use None for RGB images
plt.title("Original Image")
plt.axis('off')  # Removes axis ticks and labels
plt.show()

# %% [raw]
# Step2:
# o Draw a line from the top-left to the bottom-right of the image.
#
# o Draw a circle at the center of the image.
#
# o Draw a rectangle around a specific region of interest in the image.
#
# o Add the text "OpenCV Drawing" at the top-left corner of the image.

# %% [raw]
# Draw a line from the top-left to the bottom-right of the image

# %%
# Load the image
image = cv2.imread('Qno. 1.jpg')

# %%
# Convert BGR (OpenCV's default) to RGB (Matplotlib's expected color order)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img_rgb.shape
# Out:
# (1200, 1920, 3)

# %%
# Draw a line from top-left to bottom-right
line_img = cv2.line(img_rgb, (0, 0), (768, 600), (0, 255, 255), 4)  # cyan line, thicker

# %%
plt.imshow(line_img, cmap='viridis')  
plt.title("Image with Line")
plt.axis('off')  
plt.show()

# %% [raw]
# Draw a circle at the center of the image.

# %%
# Load the image
image = cv2.imread('Qno. 1.jpg') 

# Convert BGR (OpenCV's default) to RGB (Matplotlib's expected color order)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img_rgb.shape
# Out:
# (1200, 1920, 3)

# %%
circle_img = cv2.circle(img_rgb, (350, 250), 120, (255, 0, 255), 8)  # magenta circle, moved & resized

# %%
plt.imshow(circle_img, cmap='viridis')  
plt.title("Image with Circle")
plt.axis('off')  
plt.show()

# %% [raw]
# Draw a rectangle around  the whole image

# %%
# Load the image
image = cv2.imread('Qno. 1.jpg') 

# Convert BGR (OpenCV's default) to RGB (Matplotlib's expected color order)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img.shape
# Out:
# (1200, 1920, 3)

# %%
# Draw a rectangle around the Whole image
rectangle_img = cv2.rectangle(img_rgb, (20, 20), (748, 580), (0, 255, 0), 6)  # green rectangle, inset border

# %%
plt.imshow(rectangle_img, cmap='viridis')  
plt.title("Image with Rectangle")
plt.axis('off')  
plt.show()

# %% [raw]
# Add the text "OpenCV Drawing" at the top-left corner of the image.

# %%
# Load the image
image = cv2.imread('Qno. 1.jpg') 

# Convert BGR (OpenCV's default) to RGB (Matplotlib's expected color order)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Add text to the image
text_img = cv2.putText(img_rgb, "deepak sudharshan.b", (10, 40), cv2.FONT_HERSHEY_SIMPLEX, 1.3, (255, 165, 0), 3)  # orange text, larger font

# %%
plt.imshow(text_img, cmap='viridis')  
plt.title("Image with Text")
plt.axis('off')  
plt.show()

# %% [raw]
# Step3:
# o Convert the image from RGB to HSV and display it.
#
# o Convert the image from RGB to GRAY and display it.
#
# o Convert the image from RGB to YCrCb and display it.
#
# o Convert the HSV image back to RGB and display it.

# %%
# Load the image
image = cv2.imread('Qno. 1.jpg')

# %%
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# Original RGB Image
plt.imshow(image_rgb)
plt.title("Original RGB Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1919.5), np.float64(1199.5), np.float64(-0.5))

# %%
# Convert RGB to HSV
image_hsv = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2HSV)

# %%
# HSV Image
plt.imshow(image_hsv)
plt.title("HSV Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1919.5), np.float64(1199.5), np.float64(-0.5))

# %%
# Convert RGB to GRAY
image_gray = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2GRAY)

# %%
# Grayscale Image
plt.imshow(image_gray, cmap='gray')
plt.title("Grayscale Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1919.5), np.float64(1199.5), np.float64(-0.5))

# %%
# Convert RGB to YCrCb
image_ycrcb = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2YCrCb)

# %%
# YCrCb Image
plt.imshow(image_ycrcb)
plt.title("YCrCb Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1919.5), np.float64(1199.5), np.float64(-0.5))

# %%
# Convert HSV back to RGB
image_hsv_to_rgb = cv2.cvtColor(image_hsv, cv2.COLOR_HSV2RGB)

# %%
plt.imshow(image_hsv_to_rgb)
plt.title("HSV to RGB Image")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1919.5), np.float64(1199.5), np.float64(-0.5))

# %% [raw]
# Step4:
# o Access and print the value of the pixel at coordinates (100, 100).
#
# o Modify the color of the pixel at (200, 200) to white.

# %%
# Modify a block of pixels (250x250) to a random color, starting from (150, 150)
image[150:400, 150:400] = [128, 0, 255]  # purple-ish block (BGR order)

# %%
# Convert BGR to RGB for displaying with Matplotlib
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# Display the modified image
plt.imshow(image_rgb)
plt.title("Image with 250x250 Colored Block")
plt.axis("off")
plt.show()

# %% [raw]
# Step5:
# o Resize the original image to half its size and display it.

# %%
# Load the image
image = cv2.imread('Qno. 1.jpg')

# %%
image.shape
# Out:
# (1200, 1920, 3)

# %%
# Resize the image to 60% of its original size
resized_image = cv2.resize(image, (int(768 * 0.6), int(600 * 0.6)))  # (new_width, new_height)

# %%
# Convert BGR to RGB for displaying with Matplotlib
resized_image_rgb = cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB)

# %%
resized_image_rgb.shape
# Out:
# (360, 460, 3)

# %%
# Display the resized image
plt.imshow(resized_image_rgb)
plt.title("Resized Image (Half Size)")
plt.axis("off")
plt.show()

# %% [raw]
# Step6:
# o Crop a region of interest (ROI) from the image (e.g., a 100x100 pixel area starting at (50, 50)) and display it.

# %%
# Load the image
image = cv2.imread('Qno. 1.jpg')

# %%
image.shape
# Out:
# (1200, 1920, 3)

# %%
# Crop a 250x250 region starting from (100, 100)
roi = image[100:350, 100:350]  # Rows: 100-349, Columns: 100-349

# %%
# Convert BGR to RGB for displaying with Matplotlib
roi_rgb = cv2.cvtColor(roi, cv2.COLOR_BGR2RGB)

# %%
# Display the cropped region (ROI)
plt.imshow(roi_rgb)
plt.title("Cropped Region of Interest (ROI)")
plt.axis("off")
plt.show()

# %% [raw]
# Step7:
# o Flip the original image horizontally and display it.
#
# o Flip the original image vertically and display it.

# %%
# Load the image
image = cv2.imread('Qno. 1.jpg')

# %%
# Flip the image horizontally (left-right)
flipped_horizontally = cv2.flip(image, 1)

# %%
# Convert BGR to RGB for displaying with Matplotlib
flipped_horizontally_rgb = cv2.cvtColor(flipped_horizontally, cv2.COLOR_BGR2RGB)

# %%
# Horizontal flip
plt.imshow(flipped_horizontally_rgb)
plt.title("Flipped Horizontally")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1919.5), np.float64(1199.5), np.float64(-0.5))

# %%
# Flip the image vertically (up-down)
flipped_vertically = cv2.flip(image, 0)

# %%
# Convert BGR to RGB for displaying with Matplotlib
flipped_vertically_rgb = cv2.cvtColor(flipped_vertically, cv2.COLOR_BGR2RGB)

# %%
# Vertical flip
plt.imshow(flipped_vertically_rgb)
plt.title("Flipped Vertically")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1919.5), np.float64(1199.5), np.float64(-0.5))

# %% [raw]
# Step8:
# o Save the final modified image to your local directory.

# %%
# Save the final modified image to your local directory
cv2.imwrite('final_output.jpg', image)
print("Saved final_output.jpg")
# Out:
# Saved final_output.jpg
